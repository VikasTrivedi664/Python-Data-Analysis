# %% [markdown]
# # Seaborn Library Day 19 (Part - 2)

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\vikas\appdata\local\programs\python\python312\lib\site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\vikas\appdata\local\programs\python\python312\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\vikas\appdata\roaming\python\python312\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = sns.load_dataset('penguins')
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(x='island',y='bill_length_mm',data=df1,hue='sex')
plt.show()

# %%
import matplotlib.pyplot as plt
order1 = ['Dream','Torgersen','Biscoe']
sns.barplot(x= 'island',y='bill_length_mm',data=df1,hue='sex',order=order1)
plt.show()

# %%
order1 = ['Dream','Torgersen','Biscoe']
sns.barplot(x='sex',y='species',data=df1, hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='species'>

# %%
# histogram in seaborn library

sns.displot(x='island',y='bill_length_mm', data=df1)

# %%
sns.displot(df1['flipper_length_mm'],bins= [170,180,190,200,210,220,230,240,250,260],color='red',kde=True)
