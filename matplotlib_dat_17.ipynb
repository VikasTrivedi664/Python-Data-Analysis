# %% [markdown]
# # Matplotlib Library Day 17 (Part - 2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [10,20,30,40,50]
y = ['Hindi','English','Math','History','GK']
plt.pie(x ,labels= y)
plt.legend()
plt.show()
